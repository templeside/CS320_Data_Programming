# %% [markdown]
# # Animation

# %% [markdown]
# ## 1. Counter

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.core.display import HTML

# %%
fig, ax = plt.subplots()

# option 2:
text_counter = ax.text(0.5, 0.5, "TODO", size=64,
                       verticalalignment="center",
                       horizontalalignment="center")

def draw_frame(frame_num):
    #print(frame_num)
    
    # option 1: clear the axessubplot each time
    #ax.cla()
    #ax.text(0.5, 0.5, str(frame_num), size=64,
    #        verticalalignment="center", horizontalalignment="center")
    
    # option 2:
    text_counter.set_text(frame_num)

#draw_frame(4)

anim = FuncAnimation(fig, draw_frame, frames=10, interval=1000)
vid_html = anim.to_html5_video()
plt.close(fig)

#with open("example.html", "w") as f:
#    f.write(vid_html)

HTML(vid_html)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## 2. Motion of Shapes
#
# A red ball rolling across a black platform

# %%
fig, ax = plt.subplots()
ax.set_aspect(1)

circ = plt.Circle((0, 0.5), 0.1, color="red")
ax.add_artist(circ)

platform = plt.Rectangle((0, 0.2), 1, 0.2, color="black")
ax.add_artist(platform)

def draw_frame(frame_num):
    x = 0.1 * frame_num
    circ.center = (x, 0.5)

anim = FuncAnimation(fig, draw_frame, frames=10, interval=100)
vid_html = anim.to_html5_video()
plt.close(fig)

HTML(vid_html)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## 3. Frames Per Seconds (fps)

# %%
fig, ax = plt.subplots()
ax.set_aspect(1)

circ = plt.Circle((0, 0.5), 0.1, color="red")
ax.add_artist(circ)

platform = plt.Rectangle((0, 0.2), 1, 0.2, color="black")
ax.add_artist(platform)

# IMPORTANT VARIABLES ABOUT FRAMES/TIME
fps = 30
seconds = 8
frames = fps*seconds
interval = 1/fps * 1000

def draw_frame(frame_num):
    percent = frame_num / frames # what percent of the video is done playing
    
    width = 1
    x = percent * width 
    circ.center = (x, 0.5)

anim = FuncAnimation(fig, draw_frame, frames=frames, interval=interval)
vid_html = anim.to_html5_video()
plt.close(fig)

HTML(vid_html)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## 4. Fire Department Example

# %%
import pandas as pd
import geopandas as gpd
import requests, re

background = gpd.read_file("https://opendata.arcgis.com/datasets/db89adb17d414649a71c0f29ea73e5bf_6.geojson")

# part 1: fetch page
url = "https://www.cityofmadison.com/fire/daily-reports"
resp = requests.get(url)
resp.raise_for_status()
# Out:
# /home/charles/.local/lib/python3.8/site-packages/matplotlib/animation.py:889: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# "right" way to search this is using a tool like BeautifulSoup
# our way: regular expressions
print(resp.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
# <head>
#   <link rel="profile" href="http://www.w3.org/1999/xhtml/vocab" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="Generator" content="Drupal 7 (http://drupal.org)" />
# <link rel="canonical" href="/fire/daily-reports" />
# <link rel="shortlink" href="/node/31440" />
# <meta about="/fire" typeof="skos:Concept" property="rdfs:label skos:prefLabel" content="Fire" />
# <link rel="shortcut icon" href="https://www.cityofmadison.com/sites/default/files/template/favicon.ico" type="image/vnd.microsoft.icon" />
#     <title>Daily Reports | Fire, City of Madison, Wisconsin</title>
#   <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_pTagqbtahCBQyUvZ9iSZDQgGu3rKuAZ2T1l20H4SG3Y.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_l077gwLyHSo4tE2IAAfPTEMGUCyXIHZZWF-rbyWUwA4.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_6fI4dABjX3yKI_rPX37nVV912KkteL9LpqJEYa8L9Zo.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_ZozeUPzHK4a05uzmTchFMAd5aL3Db-wNq8Qwlq8vrdM.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_47DEQpj8HBSa-_TImW-5JCeuQeRkm5NMpJWZG3hSuFU.css" media="print" />
#
# <!--[if lt IE 9]>
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_7VCM0HPhIb35zEkEIj0Tar11iT9CIqPEdJuRhWFZVMQ.css" media="all" />
# <![endif]-->
# <link type="text/css" rel="stylesheet" href="https://www.cityofmadison.com/sites/default/files/css/css_3W9qYh8C7crjLgCmI3UU43NIBkZsPPiTEDKu3eyO0Mk.css" media="all" />
#   <!-- HTML5 element support for IE6-8 -->
#   <!--[if lt IE 9]>
#   <script src="https://cdn.jsdelivr.net/html5shiv/3.7.3/html5shiv-printshiv.min.js"></script>
#   <![endif]-->
#   <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/jquery/1.9/jquery.min.js?v=1.9.1"></script>
# <script src="https://www.cityofmadison.com/misc/jquery-extend-3.4.0.js?v=1.9.1"></script>
# <script src="https://www.cityofmadison.com/misc/jquery-html-prefilter-3.5.0-backport.js?v=1.9.1"></script>
# <script src="https://www.cityofmadison.com/misc/jquery.once.js?v=1.2"></script>
# <script src="https://www.cityofmadison.com/misc/drupal.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/ui/ui/minified/jquery.ui.core.min.js?v=1.10.2"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/ui/ui/minified/jquery.ui.widget.min.js?v=1.10.2"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/ui/ui/minified/jquery.ui.datepicker.min.js?v=1.10.2"></script>
# <script src="https://www.cityofmadison.com/misc/ui/jquery.ui.datepicker-1.13.0-backport.js?v=1.10.2"></script>
# <script src="https://www.cityofmadison.com/modules/locale/locale.datepicker.js?v=1.10.2"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/ui/external/jquery.cookie.js?v=67fb34f6a866c40d0570"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/misc/jquery.form.min.js?v=2.69"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/replace/ui/ui/minified/jquery.ui.accordion.min.js?v=1.10.2"></script>
# <script src="https://www.cityofmadison.com/misc/ajax.js?v=7.89"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/jquery_update/js/jquery_update.js?v=0.0.1"></script>
# <script src="https://www.cityofmadison.com/sites/all/themes/bootstrap/js/misc/_progress.js?v=7.89"></script>
# <script src="https://www.cityofmadison.com/sites/all/themes/cityofmadison/js/cityofmadison.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/google_analytics/googleanalytics.js?r9z863"></script>
# <script>(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-6999863-6", {"cookieDomain":"auto"});ga("send", "pageview");</script>
# <script src="https://www.cityofmadison.com/sites/all/modules/antibot/js/antibot.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/webform/js/webform.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/field_group/field_group.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/modules/hide_submit/js/hide_submit.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/themes/cityofmadison/bootstrap/js/bootstrap.min.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/themes/cityofmadison/js/intro.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/themes/cityofmadison/js/tours.js?r9z863"></script>
# <script src="https://www.cityofmadison.com/sites/all/themes/bootstrap/js/misc/ajax.js?r9z863"></script>
# <script>jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"cityofmadison","theme_token":"wkUnrj8Ri1vZwPt9p21hfO20vTe3n39e7el0PGuH_UI","jquery_version":"1.9","js":{"0":1,"1":1,"sites\/all\/themes\/bootstrap\/js\/bootstrap.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.9\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.datepicker.min.js":1,"misc\/ui\/jquery.ui.datepicker-1.13.0-backport.js":1,"modules\/locale\/locale.datepicker.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.accordion.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/themes\/bootstrap\/js\/misc\/_progress.js":1,"sites\/all\/themes\/cityofmadison\/js\/cityofmadison.js":1,"sites\/all\/modules\/google_analytics\/googleanalytics.js":1,"2":1,"sites\/all\/modules\/antibot\/js\/antibot.js":1,"sites\/all\/modules\/webform\/js\/webform.js":1,"sites\/all\/modules\/field_group\/field_group.js":1,"sites\/all\/modules\/hide_submit\/js\/hide_submit.js":1,"sites\/all\/themes\/cityofmadison\/bootstrap\/js\/bootstrap.min.js":1,"sites\/all\/themes\/cityofmadison\/js\/intro.js":1,"sites\/all\/themes\/cityofmadison\/js\/tours.js":1,"sites\/all\/themes\/bootstrap\/js\/misc\/ajax.js":1},"css":{"modules\/system\/system.base.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.datepicker.css":1,"misc\/ui\/jquery.ui.accordion.css":1,"sites\/all\/modules\/calendar\/css\/calendar_multiday.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/logintoboggan\/logintoboggan.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/siteimprove\/css\/siteimprove.css":1,"sites\/all\/modules\/video_filter\/video_filter.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"public:\/\/honeypot\/honeypot.css":1,"sites\/all\/modules\/webform\/css\/webform.css":1,"sites\/all\/libraries\/fontawesome\/css\/font-awesome.css":1,"sites\/all\/modules\/hide_submit\/css\/hide_submit.css":1,"sites\/all\/themes\/cityofmadison\/css\/city-styles.css":1,"sites\/all\/themes\/cityofmadison\/css\/print-styles.css":1,"sites\/all\/themes\/cityofmadison\/css\/less-than-IE9.css":1,"sites\/all\/themes\/cityofmadison\/css\/agencies\/fire.css":1}},"createTranslation":false,"createDetour":false,"imceAgency":"frontpage","agencyId":73,"langcode":"en","contentType":"page","isSuperUser":false,"isAdminUser":false,"shortcodeDocumentation":"","video_filter":{"url":{"ckeditor":"\/video_filter\/dashboard\/ckeditor"},"instructions_url":"\/video_filter\/instructions","modulepath":"sites\/all\/modules\/video_filter"},"hide_submit":{"hide_submit_status":true,"hide_submit_method":"disable","hide_submit_css":"hide-submit-disable","hide_submit_abtext":"","hide_submit_atext":"","hide_submit_hide_css":"hide-submit-processing","hide_submit_hide_text":"Processing...","hide_submit_indicator_style":"zoom-out","hide_submit_spinner_color":"#fff","hide_submit_spinner_lines":12,"hide_submit_hide_fx":0,"hide_submit_reset_time":25000},"jquery":{"ui":{"datepicker":{"isRTL":false,"firstDay":"0"}}},"ajax":{"edit-submit-1984596861":{"callback":"city_plugin_mailchimp_single_subscribe_form_ajax","wrapper":"email-list-subscription-20","eve ...
#   <!-- Include Typekit webfont kit - ND -->
#   <script src="https://use.typekit.net/xnl1tzf.js"></script>
#   <script>try{Typekit.load({ async: false });}catch(e){}</script>
# </head>
# <body class="com-fire daily-reports html not-front not-logged-in no-sidebars page-node page-node- page-node-31440 node-type-page i18n-en fire">
# <div id="skip-link">
#   <a href="#main-content" class="com-skip-link">Skip to main content</a>
# </div>
# <!--googleoff: all-->
# <header class="navbar navbar-inverse" id="nav-global">
#   <div class="container-fluid">
#     <div class="navbar-header">
#       <button class="navbar-toggle collapsed no-print" aria-controls="navbar" aria-expanded="false" data-target="#navbar-global" data-toggle="collapse" type="button">
#         <span class="h4">Search Menu</span>
#         <span class="sr-only">Toggle navigation</span>
# 		    <span class="bars">
#             <span class="icon-bar"></span>
#             <span class="icon-bar"></span>
#             <span class="icon-bar"></span>
#         </span>
#       </button>
#       <a id="site-name" class="h5 navbar-brand pull-left" href="/" title="City of Madison, Wisconsin">City of Madison</a>
#     </div>
#
#           <nav id="navbar-global" class="navbar-collapse collapse no-print" aria-label="City of Madison primary navigation">
#                   <ul class="navbar-nav menu nav"><li class="first expanded dropdown"><a href="/accounts" title="" class="dropdown-toggle" data-toggle="dropdown">Accounts <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="https://www.cityofmadison.com/accounts" title="">All Accounts</a></li>
# <li class="leaf"><a href="https://my.cityofmadison.com/" title="">My Account</a></li>
# <li class="leaf"><a href="https://www.cityofmadison.com/epayment/" title="">ePayments</a></li>
# <li class="leaf"><a href="https://mywater.cityofmadison.com" title="">Water Customer Care</a></li>
# <li class="leaf"><a href="https://www.governmentjobs.com/careers/MadisonWi/applications/submitted" title="">Employment</a></li>
# <li class="last leaf"><a href="https://elam.cityofmadison.com/citizenaccess" title="">Licenses &amp; Permits</a></li>
# </ul></li>
# <li class="leaf"><a href="/services" title="">Services</a></li>
# <li class="leaf"><a href="/jobs" title="">Jobs</a></li>
# <li class="expanded dropdown"><a href="//www.cityofmadison.com/agencies" title="" class="dropdown-toggle" data-toggle="dropdown">Agencies <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="//www.cityofmadison.com/agencies" title="">All Agencies</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/assessor/" title="">Assessor&#039;s Office</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/attorney/" title="">Attorney&#039;s Office</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/bi/" title="">Building Inspection</a></li>
# <li class="leaf"><a href="/civil-rights" title="">Civil Rights</a></li>
# <li class="leaf"><a href="/clerk" title="">Clerk&#039;s Office</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/council/" title="">Common Council</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/communitydevelopment/" title="">Community Development</a></li>
# <li class="leaf"><a href="/development-services-center" title="">Development Services Center</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/economicdevelopment/" title="">Economic Development</a></li>
# <li class="leaf"><a href="/employee-assistance-program" title="">Employee Assistance Program</a></li>
# <li class="leaf"><a href="/engineering" title="">Engineering</a></li>
# <li class="leaf"><a href="/finance" title="">Finance</a></li>
# <li class="leaf"><a href="/fire" title="">Fire</a></li>
# <li class="leaf"><a href="/fleet-service" title="">Fleet Service</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/parks/golf/" title="">Golf</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/parks/pool/" title="">Goodman Pool</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/housing/" title="">Housing Authority</a></li>
# <li class="leaf"><a href="/human-resources" title="">Human Resources</a></li>
# <li class="leaf"><a href="/information-technology" title="">Information Technology</a></li>
# <li class="leaf"><a href="/information-technology/city-channel" title="">Madison City Channel</a></li>
# <li class="leaf"><a href="https://www.madisonpubliclibrary.org" title="">Madison Public Library</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/senior-center" title="">Madison Senior Center</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/mayor" title="">Mayor&#039;s Office</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/metro" title="">Metro Transit</a></li>
# <li class="leaf"><a href="https://www.mononaterrace.com/" title="">Monona Terrace</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/municipalcourt" title="">Municipal Court</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/economicdevelopment/office-of-business-resources/223" title="">Office of Business Resources</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/economicdevelopment/real-estate-services-/401" title="">Office of Real Estate Services</a></li>
# <li class="leaf"><a href="http://www.olbrich.org" title="">Olbrich Botanical Gardens</a></li>
# <li class="leaf"><a href="/parking-utility" title="">Parking Utility</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/parks/" title="">Parks</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/planning" title="">Planning</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/dpced/" title="">Planning, Community &amp; Economic Development</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/police/" title="">Police</a></li>
# <li class="leaf"><a href="//www.publichealthmdc.com/" title="">Public Health Madison &amp; Dane County</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/business/pw/" title="">Public Works</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/streets/" title="">Streets &amp; Recycling</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/trafficengineering/" title="">Traffic Engineering</a></li>
# <li class="leaf"><a href="/transportation" title="">Transportation</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/finance/treasury" title="">Treasurer&#039;s Office</a></li>
# <li class="leaf"><a href="//www.cityofmadison.com/parks/wpcrc/" title="">Warner Park Community Recreation Center</a></li>
# <li class="last leaf"><a href="/water" title="">Water Utility</a></li>
# </ul></li>
# <li class="leaf"><a href="//data-cityofmadison.opendata.arcgis.com/" title="">Data</a></li>
# <li class="last expanded dropdown"><a href="/contact" title="" class="dropdown-toggle" data-toggle="dropdown">Contact <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="/mayor" title="">Mayor</a></li>
# <li class="leaf"><a href="https://www.cityofmadison.com/council/contact/" title="">City Council</a></li>
# <li class="last leaf"><a href="https://www.cityofmadison.com/contact" title="">City Staff &amp; Agencies</a></li>
# </ul></li>
# </ul>                          <div class="region region-navigation navbar-form navbar-right"><form novalidate="1" class="form-search content-search" action="/fire/daily-reports" method="post" id="search-block-form" accept-charset="UTF-8"><div><div id="global-nav-search-form">
#       <span class="element-invisible">Search form</span>
#     <div class="input-group"><input title="Enter the terms you wish to search for." placeholder="Search" class="form-control form-text" type="text" id="edit-search-block-form--2" name="search_block_form" value="" size="15" maxlength="128" /></div><div class="form-actions form-wrapper form-group" id="edit-actions"><button class="element-invisible btn btn-primary form-submit" type="submit" id="edit-submit" name="op" value="Search">Search</button>
# </div><input type="hidden" name="form_build_id" value="form-2rtg_kQQgEkr7TjFLKWDbfAeMSJGbThEDuYIatPwV9E" />
# <input type="hidden" name="form_id" value="search_block_form" />
# </div>
# </div></form></div>
#               </nav>
#       </div>
# </header>
# <!--googleon: all-->
#
#   <div class="alert-group" id="citywide-alerts-full-width"><div class="com-page">
# <!-- Sitewide Notification -->
# <!-- <div class="padding-top-5 padding-right-15 padding-bottom-5 padding-left-15 bg-yellow text-center max-width-none" role="alert">
# <h1 class="h4">Scheduled Maintenance</h1>
# <p>This website is undergoing scheduled maintenance on Sunday, April 25, 6:00&nbsp;am &ndash; 8:00&nbsp;pm. You may experience intermittent outages during this time.</p>
# </div> -->
# <!-- /Sitewide Notification -->
# <div class="sitewide-alert danger covid-alert" role="banner">
# <div class="content text-center">
# <div class="heading">Coronavirus (COVID-19)</div>
# <nav aria-label="Coronavirus (COVID-19) information links">
# <ul class="list-inline">
# 	<li class="margin-right-10"><a href="/coronavirus">City Services</a></li>
# 	<li class="margin-right-10"><a href="https://www.publichealthmdc.com/coronavirus">Public Health</a></li>
# 	<li class="margin-right-10"><a href="https://www.publichealthmdc.com/coronavirus/covid-19-vaccine">Vaccination</a></li>
# 	<li class="margin-right-10"><a href="https://www.publichealthmdc.com/coronavirus/testing">Testing</a></li>
# 	<li><a href="/es/health-safety/coronavirus" title="Coronavirus (COVID-19) - Español">Español</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div></div>
#
# <div style="background-image:url(/sites/default/files/template/banner/fire/banner3.jpg)" id="content-banner">
#   <div role="banner">
#     <div class="container-fluid">
#     <div class="row">
#       <div class="col-xs-12 col-sm-9"><div class="pull-left banner-logo"><div class="views-display">
# <div class="logo-block contextual-links-region">
#
#
#
#
#         <div>
#       <a href="/fire" class="brand"><span class="logo"><img typeof="foaf:Image" class="img-responsive" src="https://www.cityofmadison.com/sites/default/files/logos/images/firelogo.png" width="250" height="250" alt="Madison Fire Department" /></span>
# <h1 class="logo-text">City of Madison Fire Department</h1></a>    </div>
#
#
#
#
#
# </div></div></div></div>
#       <div class="col-xs-12 col-sm-3"><div class="views-display">
# <div class="banner-right hidden-xs contextual-links-region">
#
#
#
#
#         <div>
#       <p class="department-head">              Chris Carbon, Fire Chief    </p>    </div>
#
#
#
#
#
# </div></div></div>
#     </div></div>  </div>
#   <div class="navbar navbar-default main-nav no-print">
#     <div class="container-fluid">
#       <div class="navbar-header">
#         <button class="navbar-toggle collapsed" aria-controls="navbar" aria-expanded="false" data-target="#main-nav"
#                 data-toggle="collapse" type="button">
#           <span class="h4">Fire Menu</span>
#           <span class="sr-only">Toggle Navigation</span>
# 				<span class="bars">
#           <span class="icon-bar"></span>
#           <span class="icon-bar"></span>
#           <span class="icon-bar"></span>
#         </span>
#         </button>
#       </div>
#       <nav id="main-nav" class="navbar-collapse collapse" aria-label="Agency navigation">
#         <div class="region region-subnav row"><div class="menu-block-wrapper">
#   <ul class="navbar-nav menu nav"><li class="first leaf menu-mlid-4982 home"><a href="/fire" title="">Home</a></li>
# <li class="leaf has-children menu-mlid-4979 stations"><a href="/fire/stations">Stations</a></li>
# <li class="leaf has-children menu-mlid-4983 join-mfd"><a href="/fire/join-mfd">Join MFD</a></li>
# <li class="leaf has-children menu-mlid-4980 your-safety"><a href="/fire/your-safety">Your Safety</a></li>
# <li class="leaf has-children menu-mlid-4977 permits-inspections"><a href="/fire/permits-inspections">Permits &amp; Inspections</a></li>
# <li class="leaf has-children menu-mlid-4978 emergency-medical-services"><a href="/fire/emergency-medical-services">Emergency Medical Services</a></li>
# <li class="leaf menu-mlid-4984 emergency-management"><a href="/fire/emergency-management">Emergency Management</a></li>
# <li class="leaf has-children menu-mlid-4976 about"><a href="/fire/about">About</a></li>
# <li class="leaf has-children menu-mlid-4981 media"><a href="/fire/media">Media</a></li>
# <li class="last leaf has-children menu-mlid-4974 contact"><a href="/fire/contact">Contact</a></li>
# </ul></div>
# </div>
#       </nav>
#     </div>
#   </div>
# </div>
# <main class="main-container 1_column">
#   <div class="container-fluid">
#     <div class="row">
#       <div class="col-xs-12">
#
#
#         <!-- test layout for language switcher, breadcrumbs and add this -->
#         <div class="breadcrumb-wrapper">
#
# <div class=" contextual-links-region">
#
#
#
#
#
#
#
#
#
#
# </div>          <nav id="breadcrumb-navigation" aria-label="breadcrumbs">
#             <ol class="breadcrumb"><li><a href="/">City of Madison</a></li><li><a href="/fire">Fire</a></li><li>Daily Reports</li></ol>          </nav>
#                   </div>
#
#
# <div class="region-content com-page contextual-links-region">
#
#
#
#
#
#
#
#
#
#
# </div>        <div id="main-content"></div>
#                                           <h1 class="page-header">Daily Reports</h1>
#                                       </div>
#     </div>
#   </div>
#
#     <div class="region region-content">
#     <section id="block-system-main" class="block block-system">
#
#
#
# <section class="node node-page view-mode-1_column">
#
#
#
#
#   <div class="container-fluid">
#
#           <div class="row"><div class="col-md-12"><div class="com-layout row">
# <div class="col-md-8">
# <div class="com-column-one"><div class="views-display">
# <div class="pseudo-table contextual-links-region">
#
#               <div class="row hidden-xs">
#     <div class="col-xs-12 col-sm-3"><strong>Incident</strong></div>
#     <div class="col-xs-12 col-sm-2"><strong>Date</strong></div>
#     <div class="col-xs-12 col-sm-2"><strong>Incident Type</strong></div>
#     <div class="col-xs-12 col-sm-3"><strong>Address</strong></div>
#     <div class="col-xs-12 col-sm-2"><strong>Updated</strong></div>
# </div>
#
#
#         <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/kitchen-fire-on-straubel-court">Kitchen Fire On Straubel Court</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-04-09T15:17:00-05:00">04/09/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Cooking    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">Straubel Court</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/fire-destroys-cabin-in-city-sanctioned-campground">Fire Destroys Cabin in City Sanctioned Campground</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-29T13:17:00-05:00">03/29/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Structure    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">3200 Dairy Drive</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span> <span itemprop="postalCode">53718</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/hotel-fire-extinguished-by-automatic-fire-sprinkler-system">Hotel Fire Extinguished by Automatic Fire Sprinkler System</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-28T10:24:00-05:00">03/28/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Structure    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">2100 East Springs Drive</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span> <span itemprop="postalCode">53704</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/two-displaced-no-injuries-reported-in-accidental-apartment-fire">Two Displaced, No Injuries Reported In Accidental Apartment Fire</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-26T16:37:00-05:00">03/26/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Structure    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">2300 block Cypress Way</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/punctured-diesel-tank-results-in-large-fuel-spill-environmental-hazard-on">Punctured Diesel Tank Results In Large Fuel Spill, Environmental Hazard On Commercial Ave.</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-26T13:39:00-05:00">03/26/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Hazmat    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">3700 block Commercial Avenue</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/crews-respond-to-east-side-fire-cause-under-investigation">Crews Respond To East Side Fire, Cause Under Investigation</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-20T13:31:00-05:00">03/20/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Structure    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">1400 block Williamson Street</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/crews-respond-to-serious-crash-turned-vehicle-fire-on-southwest-side">Crews Respond To Serious Crash Turned Vehicle Fire On Southwest Side</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-15T17:17:00-05:00">03/15/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Vehicle    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">5400 block Raymond Road</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/five-injured-in-two-vehicle-crash">Five Injured In Two-Vehicle Crash</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-14T21:42:00-05:00">03/14/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Vehicle    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">300 block N. Sixth Street</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/one-person-rescued-from-malfunctioning-damaged-elevator-unharmed">One Person Rescued From Malfunctioning, Damaged Elevator Unharmed</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-13T16:56:00-05:00">03/13/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Elevator    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">400 block N. Park Street</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#           <div class="row">
#       <div class="col-xs-12 col-sm-3">          <strong class="visible-xs-inline-block">Incident: </strong>    <a href="/fire/daily-reports/fire-sprinkler-catches-garage-fire-early-no-residents-injured-or-displaced">Fire Sprinkler Catches Garage Fire Early, No Residents Injured Or Displaced</a>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Date: </strong>    <span class="date-display-single" property="dc:date" datatype="xsd:dateTime" content="2022-03-10T12:02:00-06:00">03/10/2022</span>    </div>
#   <div class="col-xs-12  col-sm-2">          <strong class="visible-xs-inline-block">Incident Type: </strong>    Trash/Rubbish    </div>
#   <div class="col-xs-12  col-sm-3">          <strong class="visible-xs-inline-block">Address: </strong>    <address><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">6000 block Driscoll Drive</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span></span></address>    </div>    </div>
#       <div class="text-center"><ul class="pagination"><li class="active"><span>1</span></li>
# <li><a title="Go to page 2" href="/fire/daily-reports?page=1">2</a></li>
# <li><a title="Go to page 3" href="/fire/daily-reports?page=2">3</a></li>
# <li><a title="Go to page 4" href="/fire/daily-reports?page=3">4</a></li>
# <li><a title="Go to page 5" href="/fire/daily-reports?page=4">5</a></li>
# <li><a title="Go to page 6" href="/fire/daily-reports?page=5">6</a></li>
# <li><a title="Go to page 7" href="/fire/daily-reports?page=6">7</a></li>
# <li><a title="Go to page 8" href="/fire/daily-reports?page=7">8</a></li>
# <li><a title="Go to page 9" href="/fire/daily-reports?page=8">9</a></li>
# <li class="pager-ellipsis disabled"><span>…</span></li>
# <li class="next"><a title="Go to next page" href="/fire/daily-reports?page=1">next ›</a></li>
# <li class="pager-last"><a title="Go to last page" href="/fire/daily-reports?page=183">last »</a></li>
# </ul></div>
#
#
#
#
# </div></div></div>
# </div>
#
# <div class="col-md-4">
# <div class="com-column-two">
# <div class="email-flex"><h2>Subscribe to Fire Daily Reports Email List</h2><form class="email-list-subscription" id="email-list-subscription-20" novalidate="1" action="/fire/daily-reports" method="post" accept-charset="UTF-8"><div><div class="form-group email-list-email-field"><div class="form-item form-item-email form-type-textfield"> <label class="control-label" for="edit-email">Email </label>
# <div><input class="form-control form-text" type="text" id="edit-email" name="email" value="" size="60" maxlength="128" /></div></div></div><fieldset class="form-group email-list-subscription-optout"><legend class="sr-only">Confidentiality</legend><div class="form-item form-item-optout form-type-radios"><div class="help-block">By participating on this list the Wisconsin Public Records Laws may subject your email address to disclosure to third parties. By selecting "Yes" you are requesting that we treat your email address that you have provided to this list as confidential and you are also stating that you would not participate in this service if the City is obligated to release your email address to such third party requesters.</div><div><div id="edit-optout" class="form-radios"><div class="form-item form-item-optout form-type-radio radio"> <label class="control-label" for="edit-optout-1"><input type="radio" id="edit-optout-1" name="optout" value="1" checked="checked" class="form-radio" /><strong>Yes</strong>, keep my information confidential. </label>
# </div><div class="form-item form-item-optout form-type-radio radio"> <label class="control-label" for="edit-optout-0"><input type="radio" id="edit-optout-0" name="optout" value="0" class="form-radio" /><strong>No</strong>, do <em>not</em> keep my information confidential. </label>
# </div></div></div></div></fieldset><button type="submit" id="edit-submit-1984596861" name="op" value="Subscribe" class="btn btn-default form-submit">Subscribe</button>
# <input type="hidden" name="form_build_id" value="form-5aa1q5Qobv0bBM29fpR0X4PDIIzS442uv48L0M4G9Nc" />
# <input type="hidden" name="form_id" value="city_plugin_mailchimp_single_subscribe_form" />
# <div class="url-textfield"><div class="form-item form-item-url form-type-textfield"> <label class="control-label" for="edit-url">Leave this field blank </label>
# <div><input autocomplete="off" class="form-control form-text" type="text" id="edit-url" name="url" value="" size="20" maxlength="128" /></div></div></div></div></form></div>
# <div class="views-display"><h2 class="">Stay Informed</h2>
# <div class="list contextual-links-region">
#
#
#
#
#         <ul class="list">          <li class="">
#                 <a href="https://www.cityofmadison.com/feed/dailyreport/fire" class="rss">Fire Daily Reports</a>    </li>
#       </ul>
#
#
#
#
#
# </div></div>
#
# <div class="well well-small"><h2>Find Reports</h2><form novalidate="1" action="/fire/daily-reports" method="get" id="views-exposed-form-fireincident-incident-reports" accept-charset="UTF-8"><div><div class="views-exposed-form">
#   <div class="views-exposed-widgets clearfix">
#           <div id="edit-type-wrapper" class="views-exposed-widget views-widget-filter-field_fireincident_type_value">
#                   <label for="edit-type">
#             Incident Type          </label>
#                         <div class="views-widget">
#           <div class="form-item form-item-type form-type-select"><div><select class="form-control form-select" id="edit-type" name="type"><option value="All" selected="selected">- Any -</option><option value="alarm_investigation">Alarm Investigation</option><option value="Animal rescue"> Animal rescue</option><option value="appliance">Appliance</option><option value="assist_citizen">Assist Citizen</option><option value="candle">Candle</option><option value="carbon_monoxide">Carbon Monoxide</option><option value="chimney">Chimney</option><option value="cooking">Cooking</option><option value="electrical_fire">Electrical</option><option value="elevator">Elevator</option><option value="EMS "> EMS</option><option value="excessive_heat_scorch">Excessive heat/scorch</option><option value="explosion">Explosion</option><option value="fireworks_explosion">Fireworks</option><option value="Fuel spill"> Fuel Spill</option><option value="gas_leak">Gas Leak</option><option value="hazmat">Hazmat</option><option value="lake_rescue">Lake Rescue</option><option value="Lightning strike"> Lightning Strike</option><option value="Lock out/Lock in"> Lock out/Lock in</option><option value="odor_investigation">Odor Investigation</option><option value="outdoor">Outdoor</option><option value="Power lines down">Power lines down</option><option value="smoke_scare">Smoke Scare</option><option value="smoking">Smoking</option><option value="special_rescue">Special Rescue</option><option value="structure">Structure</option><option value="trash_rubbish">Trash/Rubbish</option><option value="unauthorized_burning">Unauthorized Burning</option><option value="vehicle">Vehicle</option><option value="water_leak">Water Leak</option></select></div></div>        </div>
#               </div>
#           <div id="edit-distance-wrapper" class="views-exposed-widget views-widget-filter-distance">
#                         <div class="views-widget">
#           <div class="form-group"><div class="form-inline"><div class="form-item form-item-distance-search-distance form-type-select"> <label class="control-label" for="edit-distance-search-distance">Within </label>
# <div><select class="form-control form-select" id="edit-distance-search-distance" name="distance[search_distance]"><option value="0.25" selected="selected">0.25</option><option value="0.5">0.5</option><option value="0.75">0.75</option><option value="1">1</option><option value="2">2</option><option value="4">4</option><option value="5">5</option><option value="10">10</option></select> miles of</div></div></div></div><input type="hidden" name="distance[search_units]" value="mile" />
# <div class="form-group"><div class="form-inline"><div class="form-item form-item-distance-address form-type-textfield"> <label class="control-label element-invisible" for="edit-distance-address">Address </label>
# <div><input placeholder="Ex: 1234 E Gorham St" class="form-control form-text" type="text" id="edit-distance-address" name="distance[address]" value="" maxlength="200" /><span>,</span><span>&nbsp;Madison, WI</span></div></div></div></div>        </div>
#               </div>
#                     <div class="views-exposed-widget views-submit-button">
#       <div class="row"><div id="edit-alarm" class="form-wrapper form-group"><div class="col-xs-6"><label for="edit-alarm-min-date">Dispatch Start Date</label><div class="form-item form-item-alarm-min form-type-textfield"><div><input class="datepicker form-control form-text" autocomplete="off" type="text" id="edit-alarm-min" name="alarm[min]" value="" size="60" maxlength="128" /></div></div></div><div class="col-xs-6"><label for="edit-alarm-min-date">Dispatch End Date</label><div class="form-item form-item-alarm-max form-type-textfield"><div><input class="datepicker form-control form-text" autocomplete="off" type="text" id="edit-alarm-max" name="alarm[max]" value="" size="60" maxlength="128" /></div></div></div></div></div><div class="row"><div id="edit-arrival" class="form-wrapper form-group"><div class="col-xs-6"><label for="edit-arrival-min-date">Arrival Start Date</label><div class="form-item form-item-arrival-min form-type-textfield"><div><input class="datepicker form-control form-text" autocomplete="off" type="text" id="edit-arrival-min" name="arrival[min]" value="" size="60" maxlength="128" /></div></div></div><div class="col-xs-6"><label for="edit-arrival-min-date">Arrival End Date</label><div class="form-item form-item-arrival-max form-type-textfield"><div><input class="datepicker form-control form-text" autocomplete="off" type="text" id="edit-arrival-max" name="arrival[max]" value="" size="60" maxlength="128" /></div></div></div></div></div><div class="row"><div id="edit-controlled" class="form-wrapper form-group"><div class="col-xs-6"><label for="edit-controlled-min-date">Controlled Start Date</label><div class="form-item form-item-controlled-min form-type-textfield"><div><input class="datepicker form-control form-text" autocomplete="off" type="text" id="edit-controlled-min" name="controlled[min]" value="" size="60" maxlength="128" /></div></div></div><div class="col-xs-6"><label for="edit-controlled-min-date">Controlled End Date</label><div class="form-item form-item-controlled-max form-type-textfield"><div><input class="datepicker form-control form-text" autocomplete="off" type="text" id="edit-controlled-max" name="controlled[max]" value="" size="60" maxlength="128" /></div></div></div></div></div><button type="submit" id="edit-submit-fireincident" name="" value="Search" class="btn btn-primary form-submit">Search</button>
#     </div>
#       </div>
# </div>
# </div></form></div>
# </div>
# </div>
# </div>
# </div></div>
#
#   </div>
#
#
#   </section>
# </section> <!-- /.block -->
#   </div>
#
# </main>
#
# <footer class="no-print"><div class="add-this-footer container"><div class="row"><div class="col-xs-12"><div class="pull-right addthis-wrap">
#   <div class="addthis_toolbox addthis_default_style">
#     <ul>
#       <li><a class="addthis_counter addthis_pill_style"></a></li>
#       <li><a class="addthis_button_email"></a></li>
#       <li><a class="addthis_button_facebook"></a></li>
#       <li><a class="addthis_button_twitter"></a></li>
#       <li><a class="addthis_button_print"></a></li>
#     </ul>
#   </div>
#   <script type="text/javascript" src="//s7.addthis.com/js/250/addthis_widget.js#pubid=xa-4ffdba8e685aa0d0"></script>
# </div></div></div></div><div class="region-feedback"><noscript>
#   <style>form.antibot { display: none !important; }</style>
#   <div class="antibot-no-js antibot-message antibot-message-warning messages warning alert alert-danger">
#       <div class="content">You must have JavaScript enabled to use this form. Please enable JavaScript and reload the page.
#       If you cannot enable JavaScript, please contact <a href="mailto:webadmin@cityofmadison.com">webadmin@cityofmadison.com</a> to provide your information.      </div>
#   </div>
# </noscript>
# <div class="content-grey-overlay no-print"><div class="container-fluid"><div class="row"><div class="col-xs-12"><form class="webform-client-form webform-client-form-1606 form-inline form-was-this-helpful antibot" novalidate="1" action="/antibot" method="post" id="webform-client-form-1606" accept-charset="UTF-8"><div><div  class="form-item webform-component webform-component-hidden webform-component--page-title" style="display: none">
#  <div><input type="hidden" name="submitted[page_title]" value="Daily Reports" />
# </div>
# </div>
# <div  class="form-item webform-component webform-component-hidden webform-component--breadcrumbs" style="display: none">
#  <div><input type="hidden" name="submitted[breadcrumbs]" value="City of Madison » Fire	" />
# </div>
# </div>
# <div  class="form-item webform-component webform-component-hidden webform-component--page-url" style="display: none">
#  <div><input type="hidden" name="submitted[page_url]" value="fire/daily-reports" />
# </div>
# </div>
# <div  class="form-group form-item webform-component webform-component-radios webform-component--was-this-page-helpful-to-you webform-container-inline form-group">
#   <label class="control-label" for="edit-submitted-was-this-page-helpful-to-you">Was this page helpful to you? <span class="form-required" title="This field is required.">*</span></label>
#  <div><div id="edit-submitted-was-this-page-helpful-to-you" class="form-radios"><div class="form-item form-item-submitted-was-this-page-helpful-to-you form-type-radio"> <label class="radio-inline control-label" for="edit-submitted-was-this-page-helpful-to-you-1"><input required="required" type="radio" id="edit-submitted-was-this-page-helpful-to-you-1" name="submitted[was_this_page_helpful_to_you]" value="yes" class="form-radio" />Yes </label>
# </div><div class="form-item form-item-submitted-was-this-page-helpful-to-you form-type-radio"> <label class="radio-inline control-label" for="edit-submitted-was-this-page-helpful-to-you-2"><input required="required" type="radio" id="edit-submitted-was-this-page-helpful-to-you-2" name="submitted[was_this_page_helpful_to_you]" value="no" class="form-radio" />No </label>
# </div></div></div>
# </div>
# <div  class="form-group form-item webform-component webform-component-textfield webform-component--why-or-why-not webform-container-inline form-group">
#   <label class="control-label" for="edit-submitted-why-or-why-not">Why or why not? </label>
#  <div><input class="form-control form-text" type="text" id="edit-submitted-why-or-why-not" name="submitted[why_or_why_not]" value="" size="60" maxlength="250" /></div>
# </div>
# <input type="hidden" name="details[sid]" />
# <input type="hidden" name="details[page_num]" value="1" />
# <input type="hidden" name="details[page_count]" value="1" />
# <input type="hidden" name="details[finished]" value="0" />
# <input type="hidden" name="form_build_id" value="form-hsAWLo6VPhMBpLmrY-KB-CGmTvP2OgtZOv_3uXeX5NY" />
# <input type="hidden" name="form_id" value="webform_client_form_1606" />
# <input type="hidden" name="antibot_key" value="" />
# <div class="url-textfield"><div class="form-item form-item-url form-type-textfield"> <label class="control-label" for="edit-url">Leave this field blank </label>
# <div><input autocomplete="off" class="form-control form-text" type="text" id="edit-url" name="url" value="" size="20" maxlength="128" /></div></div></div><div class="form-actions"><button class="webform-submit button-primary btn btn-primary form-submit" type="submit" name="op" value="Submit">Submit</button>
# </div></div></form></div></div></div></div></div><div class="footer">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3">
# <div><h3>City of Madison Fire Department </h3><div class="node node-contactinfo view-mode-list">
#
#   <div class="node node-place node-teaser view-mode-teaser">
#
#   <div><address itemprop="location" itemscope="" itemtype="http://schema.org/Place"><strong>City of Madison Fire Department</strong><br><span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress"><span itemprop="streetAddress">314 W. Dayton St.</span><br><span itemprop="addressLocality">Madison</span>, <span itemprop="addressRegion">WI</span> <span itemprop="postalCode">53703</span></span></address></div></div>
#
# <ul><li>Administration Phone: <br />(608) 266-4420</li><li>Dane County Communications Non-Emergency Line: <br />(608) 255-2345</li><li>Fax: (608) 267-1100</li><li><a href="mailto:fire@cityofmadison.com">Email: fire@cityofmadison.com</a></li><li>Office Hours: M - F: 8:00 am - 4:30 pm</li><li><a href="/civil-rights/programs/disability-rights-services-program/assistive-communication/wisconsin-relay">WI Relay Service</a></li></ul></div>
#
# </div>
# </div>
#
# <div class="col-md-3">
# <div><h3>Join MFD</h3><div class="node node-flex-content view-mode-default">
#
#   <ul class="list "><li> <a href="/fire/join-mfd/talk-to-a-recruiter" title="Talk to a Recruiter">Talk to a Recruiter</a> </li><li> <a href="/fire/join-mfd/what-we-do" title="About the Job">About the Job</a> </li><li> <a href="/fire/join-mfd/about-the-process" title="About the Process">About the Process</a> </li><li> <a href="/fire/join-mfd/what-we-look-for" title="What We Look For">What We Look For</a> </li><li> <a href="/fire/join-mfd/frequently-asked-questions" title="Frequently Asked Questions">Frequently Asked Questions</a> </li></ul></div>
#
# </div>
# </div>
#
# <div class="col-md-3">
# <div><h3>I Want To...</h3><div class="node node-flex-content view-mode-default">
#
#   <ul class="list "><li> <a href="/fire/stations" title="Find my Fire Station">Find my Fire Station</a> </li><li> <a href="/fire/your-safety/smoke-alarms" title="Smoke Alarm Information">Smoke Alarm Information</a> </li><li> <a href="/fire/permits-inspections/licenses-permits/licenses-permits-applications" title="Do I Need a Permit?">Do I Need a Permit?</a> </li><li> <a href="/fire/contact/ambulance-billing" title="Pay an Ambulance Bill">Pay an Ambulance Bill</a> </li><li> <a href="/fire/contact/request-a-fire-report" title="Request a Fire Report">Request a Fire Report</a> </li></ul></div>
#
# </div>
# </div>
#
# <div class="col-md-3">
# <div><div class="views-display"><h3  class="" >Stay Informed</h3>
# <div class=" contextual-links-region">
#
#
#
#
#         <ul class="list double">          <li class="">
#                 <a href="https://www.cityofmadison.com/fire/blog/chief" class="blog">Fire Chief's Blog</a>    </li>
#           <li class="">
#                 <a href="https://www.cityofmadison.com/feed/dailyreport/fire" class="rss">Fire Daily Reports</a>    </li>
#           <li class="">
#                 <a href="https://www.cityofmadison.com/fire/blog" class="blog">Fire Department Blog</a>    </li>
#           <li class="">
#                 <a href="https://www.cityofmadison.com/contact/email-lists?category=fire" class="email-list">Fire Department Email Lists</a>    </li>
#           <li class="">
#                 <a href="https://www.facebook.com/cityofmadisonfire" class="facebook">Fire Department Facebook</a>    </li>
#           <li class="">
#                 <a href="https://www.flickr.com/photos/cityofmadison/collections/72157621641618933" class="flickr">Fire Department Flickr</a>    </li>
#           <li class="">
#                 <a href="https://www.instagram.com/madisonwifire/" class="instagram">Fire Department Instagram</a>    </li>
#           <li class="">
#                 <a href="https://twitter.com/madisonwifire" class="twitter">Fire Department Twitter</a>    </li>
#           <li class="">
#                 <a href="https://www.cityofmadison.com/feed/news/fire" class="rss">Fire News Releases</a>    </li>
#       </ul>
#
#
#
#           <p><a class="strong" href="/outreach">All Social Media &raquo;</a></p>
#
# </div></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="com-footer"><div class="container"><div class="node node-flex-content view-mode-default">
#
#   <div class="row">
# <div class="col-sm-7 col-md-8">
# <a href="/" class="com-footer-logo"><img alt="City of Madison, Wisconsin logo, copyright City of Madison" src="/sites/default/files/logos/images/banner-logo.png" /></a>
# <div><div class="node node-flex-content view-mode-default">
#
#   <p class="lead-lg margin-bottom-5">Our&nbsp;Madison – Inclusive, Innovative, &amp; Thriving</p>
# </div>
#
# </div>
#
# <div class="copyright no-margin-bottom">Copyright © 1995 - 2022 City of Madison, WI</div>
#
# <ul class="list-inline" style="display:block;">
# 	<li class="menu-550 no-padding-left"><a href="/form/website-contact-form">Contact Webmaster</a></li>
# 	<li class="menu-551"><a href="/policy/accessibility">Accessibility</a></li>
# 	<li class="menu-552"><a href="/policy">Web Policies</a></li>
# </ul>
# </div>
# <div class="col-sm-5 col-md-4 com-awards-links">
# <a href="https://www.govtech.com/dc/digital-cities/digital-cities-survey-2021-winners-announced" target="_blank" rel="noopener" class="margin-bottom-15"><img alt="2021 Winner of the Digital Cities Survey by the Center for Digital Government"  src="https://www.cityofmadison.com/sites/default/files/city-of-madison/frontpage/images/Digital-Cities-Winner-2021-White.png" /></a>
# <a href="https://medium.com/what-works-cities-certification/with-a-strong-data-foundation-madison-reaches-for-equity-goals-f45170db9d2f" target="_blank" rel="noopener" class="margin-bottom-15"><img alt="What Works Cities Silver 2021" src="/sites/default/files/city-of-madison/frontpage/images/WhatWorks-2021-White.png" /></a>
# </div>
# </div></div>
#
# </div></div></footer><script>(function ($) { $('.datepicker').datepicker(); })(jQuery);</script>
# <script>(function ($) { $('.datepicker').datepicker(); })(jQuery);</script>
# <script src="https://www.cityofmadison.com/sites/all/themes/bootstrap/js/bootstrap.js?r9z863"></script>
# <script type="text/javascript">
#   /*<![CDATA[*/
#   (function() {
#     var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
#     sz.src = '//siteimproveanalytics.com/js/siteanalyze_15203123.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
#   })();
#   /*]]>*/
# </script>
# </body>
# </html>

# %%
# part 2: extract dates
dates = re.findall(r"\d{2}/\d{2}/\d{4}", resp.text)
dates = pd.to_datetime(dates)
dates
# Out:
# DatetimeIndex(['2022-04-09', '2022-03-29', '2022-03-28', '2022-03-26',
#                '2022-03-26', '2022-03-20', '2022-03-15', '2022-03-14',
#                '2022-03-13', '2022-03-10'],
#               dtype='datetime64[ns]', freq=None)

# %%
days = (dates - dates.min()) / pd.Timedelta(days=1)
days
# Out:
# Float64Index([30.0, 19.0, 18.0, 16.0, 16.0, 10.0, 5.0, 4.0, 3.0, 0.0], dtype='float64')

# %%
# part 3: extract addresses
re.findall(r'<span itemprop="streetAddress">3200 Dairy Drive</span>', resp.text)
# Out:
# ['<span itemprop="streetAddress">3200 Dairy Drive</span>']

# %%
addresses = re.findall(r'<span itemprop="streetAddress">(.+?)</span>', resp.text)[:-1]
addresses = [addr.replace(" block ", " ") + "; Madison, WI" for addr in addresses]
addresses
# Out:
# ['Straubel Court; Madison, WI',
#  '3200 Dairy Drive; Madison, WI',
#  '2100 East Springs Drive; Madison, WI',
#  '2300 Cypress Way; Madison, WI',
#  '3700 Commercial Avenue; Madison, WI',
#  '1400 Williamson Street; Madison, WI',
#  '5400 Raymond Road; Madison, WI',
#  '300 N. Sixth Street; Madison, WI',
#  '400 N. Park Street; Madison, WI',
#  '6000 Driscoll Drive; Madison, WI']

# %%
# part 4: geocoding (addresses => lat/lon)
# Google Maps, Bing, OpenStreetMaps (nominatim)

gpd.tools.geocode(addresses[0])
# Out:
#                      geometry  \
# 0  POINT (-89.32988 43.11751)
#
#                                              address
# 0  Straubel Court, 53704, Madison, Wisconsin, Uni...

# %%
df = gpd.tools.geocode(addresses, provider="nominatim", user_agent="cs320")
df
# Out:
#                      geometry  \
# 0  POINT (-89.32988 43.11751)
# 1  POINT (-89.29605 43.05013)
# 2  POINT (-89.29678 43.12592)
# 3  POINT (-89.39734 43.04158)
# 4  POINT (-89.31781 43.10962)
# 5  POINT (-89.36074 43.08592)
# 6  POINT (-89.47174 43.03194)
# 7    GEOMETRYCOLLECTION EMPTY
# 8  POINT (-89.40072 43.07339)
# 9  POINT (-89.27963 43.09860)
#
#                                              address
# 0  Straubel Court, Madison, Dane County, Wisconsi...
# 1  Dairy Drive, Madison, Dane County, Wisconsin, ...
# 2  2100, East Springs Drive, Madison, Dane County...
# 3  2300, Cypress Way, Burr Oaks, Madison, Town of...
# 4  3700, Commercial Avenue, Madison, Dane County,...
# 5  1400, Williamson Street, Marquette, Madison, D...
# 6  5400, Raymond Road, Madison, Dane County, Wisc...
# 7                                               None
# 8  400, North Park Street, State-Langdon, Madison...
# 9  6000, Driscoll Drive, McClellan Park, Madison,...

# %%
df["date"] = dates
df["day"] = days
df = df.dropna()
df
# Out:
#                      geometry  \
# 0  POINT (-89.32988 43.11751)
# 1  POINT (-89.29605 43.05013)
# 2  POINT (-89.29678 43.12592)
# 3  POINT (-89.39734 43.04158)
# 4  POINT (-89.31781 43.10962)
# 5  POINT (-89.36074 43.08592)
# 6  POINT (-89.47174 43.03194)
# 8  POINT (-89.40072 43.07339)
# 9  POINT (-89.27963 43.09860)
#
#                                              address       date   day
# 0  Straubel Court, Madison, Dane County, Wisconsi... 2022-04-09  30.0
# 1  Dairy Drive, Madison, Dane County, Wisconsin, ... 2022-03-29  19.0
# 2  2100, East Springs Drive, Madison, Dane County... 2022-03-28  18.0
# 3  2300, Cypress Way, Burr Oaks, Madison, Town of... 2022-03-26  16.0
# 4  3700, Commercial Avenue, Madison, Dane County,... 2022-03-26  16.0
# 5  1400, Williamson Street, Marquette, Madison, D... 2022-03-20  10.0
# 6  5400, Raymond Road, Madison, Dane County, Wisc... 2022-03-15   5.0
# 8  400, North Park Street, State-Langdon, Madison... 2022-03-13   3.0
# 9  6000, Driscoll Drive, McClellan Park, Madison,... 2022-03-10   0.0

# %%
# part 5: static plot
fig, ax = plt.subplots()
background.plot(ax=ax, color="0.8")
df.plot(ax=ax, color="red")
# Out:
# <AxesSubplot:>

# %%
# part 6: animation
fig, ax = plt.subplots()

def draw_frames(frame_num):
    ax.cla()
    background.plot(ax=ax, color="0.8")
    sub_df = df[df["day"] <= frame_num]
    if len(sub_df) > 0:
        sub_df.plot(ax=ax, color="red")
    
anim = FuncAnimation(fig, draw_frames, frames=100)
vid_html = anim.to_html5_video()
plt.close(fig)

HTML(vid_html)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
